# %%
import math
from sympy import Symbol, limit, oo, sin, sqrt, solve, factorial, symbols, cos, exp, asin, atan, diff, solve, pi
import numpy as np

# %% [markdown]
# # Предел, непрерывность, ряды

# %% [markdown]
# # Пример 1

# %%
from sympy import *
x = Symbol("x")
limit((6*x**2+3*x)/(3*x**2),x,oo)
# Out:
# 2

# %% [markdown]
# # Пример 2

# %%
limit(sin(x)/x,x,0)
# Out:
# 1

# %%
limit((1+x)**(1/x),x,0)
# Out:
# E

# %%
limit((1+1/x)**x,x,oo)
# Out:
# E

# %% [markdown]
# # Односторонние пределы

# %% [markdown]
# # Пример 3

# %%
limit((2**x-1)/(x**2-3*x),x,3,'+')
# Out:
# oo

# %%
limit((2**x-1)/(x**2-3*x),x,3,'-')
# Out:
# -oo

# %% [markdown]
# # Пример 4

# %%
from sympy import *
х=Symbol("х")
limit((5**x-5*7**x)/(4*5**x-3*7**x),x,oo)
# Out:
# 5/3

# %%
from sympy import *
х=Symbol("х")
limit((7*8**x+2*9**x)/(6*8**x-6*9**x),x,-oo)
# Out:
# 7/6

# %%
limit (sqrt(x*(x+3))-sqrt(x**2+9),x,-oo)
# Out:
# -3/2

# %% [markdown]
# # Пример 5

# %%
from sympy import *
x=Symbol("x")
print(solve(x**3-9*x**2+14*x))
# Out:
# [0, 2, 7]

# %%
limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)),x,0,'-')
# Out:
# oo

# %%
limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)),x,0,'+')
# Out:
# oo

# %%
limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)),x,2,'-')
# Out:
# 1/2

# %%
limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)),x,2,'+')
# Out:
# 1/2

# %%
limit(abs((х-2)*(х-7)/(х**3-9*х**2+14*х)),х,7,'-')
# Out:
# 1/7

# %%
limit(abs((х-2)*(х-7)/(х**3-9*х**2+14*х)),х,7,'+')
# Out:
# 1/7

# %% [markdown]
# # Пример 6

# %%
k=limit((1+5*x)/(3+x)/x,x,oo)
print(k)
# Out:
# 0

# %%
b=limit((1+5*x)/(3+x)-k*x,x,oo)
print(b)
# Out:
# 5

# %%
solve(3+x)
# Out:
# [-3]

# %%
limit ((1+5*х)/(3+х),х,-3, '-')
# Out:
# oo

# %%
limit ((1+5*х)/(3+х),х,-3, '+')
# Out:
# -oo

# %% [markdown]
# # Пример 7

# %%
from sympy import *
import math as m
x=symbols('x')
limit(1/factorial(x)/(1/factorial(x+1)),x,oo)
# Out:
# oo

# %% [markdown]
# # Пример 8

# %%
import math
from sympy import*
x=Symbol("x")
limit (x**x/factorial(x)/((x+1)**(x+1)/factorial(x+1)),x,oo)
# Out:
# exp(-1)

# %% [markdown]
# # Пример 9

# %%
import sympy
х = symbols('х')
func = sin(x)
x0=0
print((func).series(x, x0, 10))
# Out:
# x - x**3/6 + x**5/120 - x**7/5040 + x**9/362880 + O(x**10)

# %%
import sympy
x = sympy.symbols('x')
func = cos(x)
x0=0
print((func).series(x, x0, 10))
# Out:
# 1 - x**2/2 + x**4/24 - x**6/720 + x**8/40320 + O(x**10)

# %%
import sympy
x = sympy.symbols('x')
func = exp(x)
x0=0
print((func).series(x, x0, 10))
# Out:
# 1 + x + x**2/2 + x**3/6 + x**4/24 + x**5/120 + x**6/720 + x**7/5040 + x**8/40320 + x**9/362880 + O(x**10)

# %%
func=asin(x)
X0=0
func.series(x,x0,10)
# Out:
# x + x**3/6 + 3*x**5/40 + 5*x**7/112 + 35*x**9/1152 + O(x**10)

# %% [markdown]
# # Примеры решения задач

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
import sympy
n=sympy.symbols('n')
limit((6*n**2+1)/(7*n**2-3*n+9),n,oo)
# Out:
# 6/7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
n=sympy.symbols('n')
limit((-7*n+10)/sqrt(9*n**2+10*n),n,oo)
# Out:
# -7/3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
n=sympy.symbols('n')
limit(sqrt(5*n**14-3*n**8+2*n-1)/(2*n**7-8*n**4+1),n,oo)
# Out:
# sqrt(5)/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
x=sympy.symbols('x')
limit((-5*x**2-8*x-4)/(2*x**2-x-2),x,oo)
# Out:
# -5/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
x=sympy.symbols('x')
limit(x*(sqrt(5*x**2+6)-sqrt(5*x**2-6)),x,-oo)
# Out:
# -6*sqrt(5)/5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
x=sympy.symbols('x')
limit(1/(sqrt(2*x**2+2*x-3)-sqrt(2*x**2-5*x-5)),x,-oo)
# Out:
# -2*sqrt(2)/7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
x=sympy.symbols('x')
limit(9*(1-х**(1/7))/(х**(1/8)-1), x,1)
# Out:
# (9 - 9*х**0.142857142857143)/(х**0.125 - 1)

# %% [markdown]
# # Задачи для самостоятельного решения

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
n=sympy.symbols('n')
limit((4*n**6+8*n**5-6*n**3+5*n-1)/(-8*n**6+6*n**5-5*n**2+n),n,oo)
# Out:
# -1/2

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
import sympy
n=sympy.symbols('n')
limit((9*n+(4*sin(4*n)**3)+8)/(8*n+(6*cos(4*n)**6)-4),n,oo)
# Out:
# 9/8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
n=sympy.symbols('n')
limit((n**3/(n**2+3*n+1)-n),n,oo)
# Out:
# -3

# %% [markdown]
# ![image.png](attachment:image.png) ![image-3.png](attachment:image-3.png)

# %%
import sympy
n=sympy.symbols('n')
limit((2-3*n) / (sqrt(n**2-n+1)-sqrt(25*n**2+2*n+1)),n,oo)
# Out:
# 3/4

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
import sympy
n=sympy.symbols('x')
limit((7*(6**(x+4))+9)/(5-7*6**(x+7)),x,-oo)
# Out:
# 9/5

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
import sympy
n=sympy.symbols('x')
limit((4*x+4) / (5-2*ln(2*x)),x,+oo)
# Out:
# -oo

# %% [markdown]
# # Индивидуальное задание

# %% [markdown]
# # Численное интегрирование

# %%
from numpy import ones,copy,cos,tan,pi,linspace

def gaussxw(N):

    # Начальное приближение к корням многочлена Лежандра
    a = linspace(3,4*N-1,N)/(4*N+2)
    x = cos(pi*a+1/(8*N*N*tan(a)))

    # Найдите корни, используя метод Ньютона
    epsilon = 1e-15
    delta = 1.0
    while delta>epsilon:
        p0 = ones(N,float)
        p1 = copy(x)
        for k in range(1,N):
            p0,p1 = p1,((2*k+1)*x*p1-k*p0)/(k+1)
        dp = (N+1)*(p0-x*p1)/(1-x*x)
        dx = p1/dp
        x -= dx
        delta = max(abs(dx))

    # Рассчитайте веса
    w = 2*(N+1)*(N+1)/(N*N*(1-x*x)*dp*dp)

    return x,w

def gaussxwab(N,a,b):
    x,w = gaussxw(N)
    return 0.5*(b-a)*x+0.5*(b+a),0.5*(b-a)*w

# %%
def f(x):
    return x**4 - 2*x + 1

N = 10
a = 0.0
b = 2.0
h = (b-a)/N

s = 0.5*f(a) + 0.5*f(b)
for k in range(1,N):
    s += f(a+k*h)

print(h*s)
# Out:
# 4.50656

# %%
def f(x):
    return x**4 - 2*x + 1

N = 3
a = 0.0
b = 2.0

# Вычислите точки выборки и веса, затем сопоставьте их
# к требуемому домену интеграции
x,w = gaussxw(N)
xp = 0.5*(b-a)*x + 0.5*(b+a)
wp = 0.5*(b-a)*w

# Выполните интеграцию
s = 0.0
for k in range(N):
    s += wp[k]*f(xp[k])

print(s)
# Out:
# 4.4000000000000075

# %%
# Методы интеграции
from scipy.integrate import quad
from pylab import loglog, show, xlabel, ylabel, legend
from sympy import integrate, symbols
from math import sin, cos
from numpy import sum, linspace

def trapezoid(a,b,N):
    h = (b-a)/N
    sum = 0.5*(f(a)+f(b))
    x = a
    for i in range(1,N):
        x += h
        sum += f(x)
    return sum*h

def simpson(a,b,f,N):
    h = (b-a)/N
    x = linspace(a,b,N+1)
    y = f(x)
    return h/3.*sum(y[0:-1:2] + 4*y[1::2] + y[2::2])

def f(x):
    return x**4 - 2*x + 1
a=0.
b=2.
TrapezoidResiduals = []
SimpsonResiduals = []
Nsteps = [] 
x = symbols('x')
IntAnalytic = integrate(x**4 - 2*x + 1, (x, a, b))
integr = integrate(x**4 - 2*x + 1)
print(integr.subs(x,b))
IntScipy = quad(f,a,b)[0]
for i in range(10):
    N = 2**i
    Nsteps.append(N)
    TrapezoidResiduals.append(abs(trapezoid(a,b,N)-IntScipy))
    SimpsonResiduals.append(abs(simpson(a,b,f,N)-IntScipy))
print (SimpsonResiduals)

loglog(Nsteps,TrapezoidResiduals, '-r', label='trapeziod')
loglog(Nsteps,SimpsonResiduals, '-b', label='simpson')
xlabel('N')
ylabel('error')
legend()
show()
# Out:
# 4.40000000000000
# [4.3999999999999995, 0.2666666666666666, 0.016666666666666607, 0.0010416666666666075, 6.510416666660745e-05, 4.069010416607455e-06, 2.5431315098245477e-07, 1.5894571880892272e-08, 9.934106870446158e-10, 6.208811242913725e-11]
