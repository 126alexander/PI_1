# %%
import sympy
import math
import mpmath
import cmath

# %% [markdown]
# # Действия над комплексными числами

# %% [markdown]
# # Пример №1

# %%
x=complex(1,3)
y=complex(2,-1)
z=x*y
print(z)
g=complex(1,-2)
print(g)
t=complex(10,0)
print(t)
h=t/g
print(h)
p=complex(-1,-1)
n=p*p
print(n)
C=z+h+n
print(C)
# Out:
# (5+5j)
# (1-2j)
# (10+0j)
# (2+4j)
# 2j
# (7+11j)

# %% [markdown]
# # Пример №2

# %%
x=complex(0,1)
y=pow(x,2) #Степень
print(y)
# Out:
# (-1+0j)

# %% [markdown]
# # Пример №3

# %%
x=complex(1,3)
y=complex(2,-1)
z=x*y
print(z)
g=complex(1,-2)
print(g)
t=complex(10,0)
print(t)
h=t/g
print(h)
p=complex(-1,-1)
n=p*p
print(n)
C=z+h+n
print(C)
# Out:
# (5+5j)
# (1-2j)
# (10+0j)
# (2+4j)
# 2j
# (7+11j)

# %% [markdown]
# # Пример №4

# %%
import math
from sympy import*
x = Symbol("x")
print(solve(x**2-2*x+5))
# Out:
# [1 - 2*I, 1 + 2*I]

# %% [markdown]
# # Пример №5

# %%
x=complex(1,-2)
i=complex(0,1)
f=x**4+(2+i)/x-(-3+2*i)
print (f)
# Out:
# (-4+23j)

# %% [markdown]
# # Пример №6

# %%
print((1 + i)**8/(1+i)**6)
# Out:
# (-0+2j)

# %% [markdown]
# # Пример №7

# %%
mpmath.mp.dps = 3
x = Symbol('x')
y = Symbol('y')
i = complex(0, 1)
fl = (2 + i) * x + y * (2 - i) - 6
f2 = (2 - i) * x + (3 - 2 * i) * y - 8
print(sympy.nsolve((fl, f2), (x, y), (-1, 1)))
# Out:
# Matrix([[-0.0588 - 0.765*I], [1.82 + 1.71*I]])

# %% [markdown]
# # Пример №8

# %%
solve(x**2-3+4*i)
# Out:
# [-2.0 + 1.0*I, 2.0 - 1.0*I]

# %% [markdown]
# # Пример №9

# %%
x=Symbol("х")
i=complex(0,1)
print(solve((2+i)*x**2-(5-i)*x+2-2*i))
# Out:
# [0.8 - 0.4*I, 1.0 - 1.0*I]

# %% [markdown]
# # Пример №10

# %%
x=Symbol("x")
i=complex(0,1)
print(solve(x**2-3+4*i))
# Out:
# [-2.0 + 1.0*I, 2.0 - 1.0*I]

# %% [markdown]
# # Пример №11

# %%
i=complex(0,1)
print(-(3+5*i)**10-25*(3*i-9)/ 2+8*i)
# Out:
# (28984688.5+34989570.5j)

# %% [markdown]
# # Пример №12

# %%
abs(z)
# Out:
# 7.0710678118654755

# %%
z=complex(2,2*sqrt(3))
cmath.phase(z)
round(math.degrees(cmath.phase(z)))
# Out:
# 60

# %% [markdown]
# # Пример №13

# %%
zl=complex(-4,-9)
z2=complex(1,-8)
complex(zl-conjugate(z2))/complex(z2+conjugate(zl))
# Out:
# (-0.19999999999999982+5.6000000000000005j)

# %%
i=complex(0,1)
print((1+2*1)*(-1+5*1)/(6-i))
# Out:
# (1.9459459459459458+0.3243243243243243j)

# %%
z=complex(1,2)
p=(1+3*1)*2**2+(-5+6*i)*2+(2-1)
print(p)
# Out:
# (7+12j)

# %% [markdown]
# # Примеры решения задач

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z1=-4-9*1j
z2=1-8*1j
print((z1-z2.conjugate())/(z1.conjugate()+z2))
# Out:
# (-0.19999999999999982+5.6000000000000005j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=2+2*math.sqrt(3)*1j
fi=round(math.degrees(cmath.phase(z)))
print(fi)
r=abs(z)
print(r)
# Out:
# 60
# 4.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=-3+3*math.sqrt(3)*1j
fi=round(math.degrees(cmath.phase(z)))
print(fi)
r=abs(z)
print(r)
# Out:
# 120
# 6.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z1=1-2j
z2=1+1j
print(z1/z2.conjugate()+z2/z1)
# Out:
# (1.3+0.09999999999999998j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z1=-1-9j
z2=2-3j
print((z1-z2.conjugate())/(z1.conjugate()+z2))
# Out:
# (-2.0270270270270268+0.16216216216216214j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z=1+3j
p=(-4+4j)*(z*z)+(-1+3j)*z+(-2-3j)
print(p)
# Out:
# (-4-59j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=complex(-8,-8)
round(math.degrees(cmath.phase(z))), abs(z)
# Out:
# (-135, 11.313708498984761)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
((1+2j)*(-1+5j))/(6-1j)
# Out:
# (-1.8648648648648647+0.1891891891891892j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
from sympy import *
x=Symbol("x")
print(solve(x**2+8*x+20))
# Out:
# [-4 - 2*I, -4 + 2*I]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=complex(-6,0)
round(math.degrees(cmath.phase(z))), abs(z)
# Out:
# (180, 6.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z=-6-2j
p=(-4+3j)*(z*z)+(5-4j)*z+(-2-1j)
print(p)
# Out:
# (-240+13j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=complex(6,6)
print(round(math.degrees(cmath.phase(z))))
r=abs(z)
print(r)
c=r*(math.cos(-45)+1j*math.sin(-45))
print(c)
# Out:
# 45
# 8.48528137423857
# (4.4575048871930445-7.220155828003307j)

# %% [markdown]
# # Задачи для самостоятельного решения

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=complex(-8,0)
round(math.degrees(cmath.phase(z))), abs(z)
# Out:
# (180, 8.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=complex(1,math.sqrt(3))
round(math.degrees(cmath.phase(z))), abs(z)
# Out:
# (60, 2.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=complex(2,2*math.sqrt(3))
round(math.degrees(cmath.phase(z))), abs(z)
# Out:
# (60, 4.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import cmath
z=complex(11,11)
round(math.degrees(cmath.phase(z))), abs(z)
# Out:
# (45, 15.556349186104045)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import math
import cmath
z=complex(-(8/16), -(8/16))
round(math.degrees(cmath.phase(z))), abs(z)
# Out:
# (-135, 0.7071067811865476)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
from sympy import *
x=Symbol("x")
print(solve(x**2+14*x+53))
# Out:
# [-7 - 2*I, -7 + 2*I]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
from sympy import *
x=Symbol("x")
print(solve(x**2-8*x+65))
# Out:
# [4 - 7*I, 4 + 7*I]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
from sympy import *
x=Symbol("x")
print(solve(x**2-x+4))
# Out:
# [1/2 - sqrt(15)*I/2, 1/2 + sqrt(15)*I/2]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
z=1+134j
p=(1000004+3000999j)*(z*z)+(5+1j)*z+(-4+4j)
print(p)
# Out:
# (-18759339685-53614935298j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z=2+1j
p=(1+3j)*(z*z)+(1+1j)*z+(1+1j)
print(p)
# Out:
# (-7+17j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z1=-1-1j
z2=1+4j
print((z1/z2.conjugate())-(z2.conjugate()/z1))
# Out:
# (-1.3235294117647058-2.7941176470588234j)

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %%
z1=1+7j
z2=-3-9j
(z1+z2.conjugate())/(z1.conjugate()-z2)
# Out:
# (1.2+3.4j)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %%
(5-1j)/(1j+4)
# Out:
# (1.1176470588235294-0.5294117647058824j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
((2+3j)*(-5+5j))/(4-1j)
# Out:
# (-5.588235294117647-2.6470588235294117j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
((2+3j)**8)/((1-1j)**6)
# Out:
# (3570+29.875j)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
((-2+3j)**10)/((3-3j)**4)
# Out:
# (1054.0895061728395-449.5925925925926j)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
print(sympy.solve(x**2 - 1 - 1j))
# Out:
# [-1.09868411346781 - 0.455089860562227*I, 1.09868411346781 + 0.455089860562227*I]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(sympy.solve(x**5 - 1 + 1j))
# Out:
# [-0.954957147571795 - 0.486574969864436*I, -0.757858283255199 + 0.757858283255199*I, 0.167662308256181 - 1.05857815270638*I, 0.486574969864436 + 0.954957147571795*I, 1.05857815270638 - 0.167662308256181*I]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import Symbol, nsolve
import sympy
import mpmath
mpmath.mp.dps = 3
x = Symbol('x')
y = Symbol('y')
i = complex(0, 1)
fl = (2 + 3j) * x + (2 - 3j) * y + 2
f2 = (-2 + 2j) * x + (-2 + 3j) * y - 3
print(sympy.nsolve((fl, f2), (x, y), (-1, 1)))
# Out:
# Matrix([[-0.2*I], [-0.492 - 0.538*I]])

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
from sympy import Symbol, nsolve
import sympy
import mpmath
mpmath.mp.dps = 3
x = Symbol('x')
y = Symbol('y')
i = complex(0, 1)
fl = (1 + 3j) * x + (-1 + 2j) * y - 12
f2 = (-1 + 2j) * x + (-1 + 3j) * y - 15
print(sympy.nsolve((fl, f2), (x, y), (-1, 1)))
# Out:
# Matrix([[0.0462 - 0.831*I], [-1.62 - 3.92*I]])

# %% [markdown]
# # Решение собственной задачи с использованием комплексных чисел

# %% [markdown]
# Представить в алгебраической форме комплексное число, модуль которого равен 2, а аргумент pi/2.

# %%
import math
arg = math.pi / 2
mod = 2
from math import sin, cos

x, y = cos(arg) * mod, sin(arg) * mod
z = complex(x, y)

print( f"x = {x}")
print( f"y = {y}")
print( f"z = {z}")
print( z.imag / z.real )
print( math.tan(math.pi / 2) )
print( (z.real ** 2 + z.imag ** 2) ** 0.5 )
# Out:
# x = 1.2246467991473532e-16
# y = 2.0
# z = (1.2246467991473532e-16+2j)
# 1.633123935319537e+16
# 1.633123935319537e+16
# 2.0
